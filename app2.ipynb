# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\vaibh\Downloads\student-dataset-null.csv")
data.drop(columns=['ethnic.group'], inplace=True)

# %%
data.isna().sum().sum()
# Out:
# 336

# %%
data.shape
# Out:
# (307, 15)

# %%
data.tail(20)
# Out:
#       id                   name               nationality         city  \
# 283  283         Jesse Carballo                  Colombia       Bogotá
# 284  284        Robert Podolski  United States of America      Oakland
# 285  285  Viridiana Ballesteros                    Brazil      Alfenas
# 286  286        Michael Griffin  United States of America     New York
# 288  288       Weldon Hightower  United States of America     New York
# 289  289          Daniel Pierce  United States of America     New York
# 290  290    Michaela Schoenbeck  United States of America      Rexburg
# 291  291          Charles Prose  United States of America        Miami
# 292  292    Brittany Kemmerzell  United States of America     New York
# 293  293      Taryn Springfield                    Canada    Vancouver
# 294  294         Matthew Obourn  United States of America    San Diego
# 295  295            Travis Poss  United States of America  Los Angeles
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  307 non-null    int64
#  1   name                307 non-null    object
#  2   nationality         307 non-null    object
#  3   city                307 non-null    object
#  4   latitude            307 non-null    float64
#  5   longitude           307 non-null    float64
#  6   gender              307 non-null    object
#  7   age                 304 non-null    float64
#  8   english.grade       304 non-null    float64
#  9   math.grade          301 non-null    float64
#  10  sciences.grade      305 non-null    float64
#  11  language.grade      299 non-null    float64
#  12  portfolio.rating    304 non-null    float64
#  13  coverletter.rating  306 non-null    float64
#  14  refletter.rating    304 non-null    float64
# ...

# %%
sns.heatmap(data.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.shape
# Out:
# (280, 15)

# %%
data.isnull().sum()
# Out:
# id                    0
# name                  0
# nationality           0
# city                  0
# latitude              0
# longitude             0
# gender                0
# age                   0
# english.grade         0
# math.grade            0
# sciences.grade        0
# language.grade        0
# portfolio.rating      0
# coverletter.rating    0
# refletter.rating      0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# id                    0
# name                  0
# nationality           0
# city                  0
# latitude              0
# longitude             0
# gender                0
# age                   0
# english.grade         0
# math.grade            0
# sciences.grade        0
# language.grade        0
# portfolio.rating      0
# coverletter.rating    0
# refletter.rating      0
# dtype: int64
