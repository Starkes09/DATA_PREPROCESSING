# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\vaibh\Downloads\student-dataset-null.csv")
data.isnull().sum()
# Out:
# id                      0
# name                    0
# nationality             0
# city                    0
# latitude                0
# longitude               0
# gender                  0
# ethnic.group          307
# age                     3
# english.grade           3
# math.grade              6
# sciences.grade          2
# language.grade          8
# portfolio.rating        3
# coverletter.rating      1
# refletter.rating        3
# dtype: int64

# %%
(data.isnull().sum()/data.shape[0]*data.shape[1])*100
# Out:
# id                       0.000000
# name                     0.000000
# nationality              0.000000
# city                     0.000000
# latitude                 0.000000
# longitude                0.000000
# gender                   0.000000
# ethnic.group          1600.000000
# age                     15.635179
# english.grade           15.635179
# math.grade              31.270358
# sciences.grade          10.423453
# language.grade          41.693811
# portfolio.rating        15.635179
# coverletter.rating       5.211726
# refletter.rating        15.635179
# dtype: float64

# %%
(data.isnull().sum().sum()/data.shape[0]*data.shape[1])*100
# Out:
# 1751.14006514658

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
